# %% [markdown]
# 1. What does an empty dictionary&#39;s code look like?

# %% [markdown]
# <b>Ans.</b> An empty dictionary is often represented by two empty curly brackets.
# d = {} or d = dict()

# %% [markdown]
# 2. What is the value of a dictionary value with the key &#39;foo&#39; and the value 42?

# %% [markdown]
# <b>Ans.</b>{'foo':42}

# %% [markdown]
# 3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# <b>Ans.</b>Dictionaries are represented by {} where as listed are represented by [].
# The Items stored in a dictionary are Unordered , while the items in a list are ordered

# %% [markdown]
# 4. What happens if you try to access spam[&#39;foo&#39;] if spam is {&#39;bar&#39;: 100}?

# %% [markdown]
# <b>Ans.</b>we will get a keyError KeyError: 'foo'

# %% [markdown]
# 5. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.keys()?

# %% [markdown]
# <b>Ans.</b>There is no difference . The operator checks whether a value exits as a key in the dictionary or not

# %% [markdown]
# 6. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.values()?

# %% [markdown]
# <b>Ans.</b>'cat' in spam checks whether there is a 'cat' key in the dictionary, while 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam.

# %% [markdown]
# 7. What is a shortcut for the following code?
# if &#39;color&#39; not in spam:
# spam[&#39;color&#39;] = &#39;black&#39;

# %% [markdown]
# <b>Ans.</b>spam.setdefault('color','black')

# %% [markdown]
# 8. How do you &quot;pretty print&quot; dictionary values using which module and function?

# %% [markdown]
# <b>Ans.</b>We can pretty print a dictionary using three functions:<br>
#     1. by using pprint() function of pprint module<br>
#             Note: pprint() function doesnot prettify nested dictionaries<br>
#     2. by using dumps() method of json module<br>
#     3. by using dumps() method of yaml module<br>

# %%
dict = [
  {'Name': 'Yash', 'Age': '25', 'Residence': {'Country':'India', 'City': 'Mumbai'}},
  {'Name': 'Ram', 'Age': '34', 'Residence': {'Country':'India', 'City': 'Bengaluru'}},
  {'Name': 'Anil', 'Age': '56', 'Residence': {'Country':'India', 'City': 'Delhi'}},
  {'Name': 'Sunny', 'Age': '24', 'Residence': {'Country':'India', 'City': 'Chennai'}}
]

print('Printing using print() function\n',dict)
print('-'*100)
import pprint
print('Printing using pprint() funciton')
pprint.pprint(dict)
print('-'*100)
import json
dump = json.dumps(dict, indent=4)
print('Printing using dumps() method\n', dump)
print('-'*100)
import yaml
dump = yaml.dump(dict)
print('Printing using dump() method\n', dump)
# Out:
# Printing using print() function
#  [{'Name': 'Yash', 'Age': '25', 'Residence': {'Country': 'India', 'City': 'Mumbai'}}, {'Name': 'Ram', 'Age': '34', 'Residence': {'Country': 'India', 'City': 'Bengaluru'}}, {'Name': 'Anil', 'Age': '56', 'Residence': {'Country': 'India', 'City': 'Delhi'}}, {'Name': 'Sunny', 'Age': '24', 'Residence': {'Country': 'India', 'City': 'Chennai'}}]
# ----------------------------------------------------------------------------------------------------
# Printing using pprint() funciton
# [{'Age': '25',
#   'Name': 'Yash',
#   'Residence': {'City': 'Mumbai', 'Country': 'India'}},
#  {'Age': '34',
#   'Name': 'Ram',
#   'Residence': {'City': 'Bengaluru', 'Country': 'India'}},
#  {'Age': '56',
#   'Name': 'Anil',
#   'Residence': {'City': 'Delhi', 'Country': 'India'}},
#  {'Age': '24',
#   'Name': 'Sunny',
#   'Residence': {'City': 'Chennai', 'Country': 'India'}}]
# ----------------------------------------------------------------------------------------------------
# Printing using dumps() method
#  [
#     {
#         "Name": "Yash",
#         "Age": "25",
#         "Residence": {
#             "Country": "India",
#             "City": "Mumbai"
#         }
#     },
#     {
#         "Name": "Ram",
#         "Age": "34",
#         "Residence": {
#             "Country": "India",
#             "City": "Bengaluru"
#         }
#     },
#     {
#         "Name": "Anil",
#         "Age": "56",
#         "Residence": {
#             "Country": "India",
#             "City": "Delhi"
#         }
#     },
#     {
#         "Name": "Sunny",
#         "Age": "24",
#         "Residence": {
#             "Country": "India",
#             "City": "Chennai"
#         }
#     }
# ]
# ----------------------------------------------------------------------------------------------------
# Printing using dump() method
#  - Age: '25'
#   Name: Yash
#   Residence:
#     City: Mumbai
#     Country: India
# - Age: '34'
#   Name: Ram
#   Residence:
#     City: Bengaluru
#     Country: India
# - Age: '56'
#   Name: Anil
#   Residence:
#     City: Delhi
#     Country: India
# - Age: '24'
#   Name: Sunny
#   Residence:
#     City: Chennai
#     Country: India
